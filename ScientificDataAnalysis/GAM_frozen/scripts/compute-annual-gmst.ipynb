# %% [markdown]
# # Compute the annual temperature anomaly from Temperature12k
#
# This notebooks computes GMST using Generalized Additive Models (GAM).
#
# The main output is a netCDF file `annual-with-single-seas-gam-band-means.nc` with the temperature anomaly with reference to the 5000-3000 year BP period for the six latitudinal bands -90 to -60, -60 to -30, -30 to 0, 0 to 30, 30 to 60 and 60 to 90 degrees North.
#
# This notebook is divided into four sections.
#
# 1. [Read the LiPD files](#lipds)
# 2. [Transform them into a combined dataframe](#pandas)
# 3. [Compute the grid cell anomalies](#cell-anomalies)
# 4. [Compute the band means](#band-anomalies)
#
# Note that you have to set the [version for the database](#db_version) manually.

# %%
import pandas as pd
import numpy as np
import os.path as osp
import os
from urllib import request
import zipfile
import pickle
from openpyxl import load_workbook
import matplotlib.pyplot as plt
import warnings
import xarray as xr
import multiprocessing as mp
import psyplot.data as psyd
import gam_ensemble as ge
import pyleogrid as pg
from distributed import Client
import psyplot.project as psy
from dask_jobqueue import SLURMCluster
from matplotlib.animation import FuncAnimation
import contextlib
from sklearn.neighbors import BallTree
from latlon_utils import get_climate
import lipd

# %% [markdown]
# ## Read the LiPD files <a name="lipds"></a>
# In this section we read the temperature from the LiPD files. This involves some [filtering](#filter) to only keep the necessary temperature series. Note however, that samples with NaN are filtered [down below](#filter-nan).
#
# <a id=db_version></a>Read in the LipD data from http://lipdverse.org/globalHolocene/current_version
#
# You should set the latest version here manually!

# %%
# %matplotlib inline

# %%
db_version = '1_0_0'

# %%
lipd_dir = f'../lipds_{db_version}'

# %% [markdown]
# Download the LiPD file if the input directory does not yet exist

# %%
# %%time
if not osp.exists(lipd_dir):
    os.makedirs(lipd_dir)
    zipped = f'Temp12k_v{db_version}_LiPD.zip'
    uri = f'https://www1.ncdc.noaa.gov/pub/data/paleo/reconstructions/climate12k/temperature/version{db_version.replace("_", ".")}/{zipped}'
    target = osp.join(lipd_dir, zipped)
    print('downloading ' + uri)
    request.urlretrieve(uri, target)
    with zipfile.ZipFile(target) as f:
        f.extractall(lipd_dir)
# Out:
# CPU times: user 65 µs, sys: 14 µs, total: 79 µs
# Wall time: 70.1 µs

# %%
@contextlib.contextmanager
def remember_cwd():
    """Context manager to switch back to the current working directory

    Usage::

        with remember_cwd():
            os.chdir('test')
            print(os.getcwd())  # test
        print(os.getcwd())      # test/.."""
    curdir = os.getcwd()
    try:
        yield
    except:
        raise
    finally:
        os.chdir(curdir)

# %% [markdown]
# Load the data from the LiPD files it is has not yet been serialized as a pickled object.

# %%
# %%time
pickle_file = f'{lipd_dir}/lipds.pkl'
if osp.exists(pickle_file):
    with open(pickle_file, 'rb') as f:
        data = pickle.load(f)
else:
    with remember_cwd():
        os.chdir(f'{lipd_dir}/')
        data = lipd.readLipd('.')
    with open(pickle_file, 'wb') as f:
        pickle.dump(data, f)
# Out:
# CPU times: user 137 ms, sys: 55.8 ms, total: 193 ms
# Wall time: 192 ms

# %% [markdown]
# Extract the individual time-series from the LiPD files

# %%
# %%time
all_series = lipd.extractTs(data)
# Out:
# extracting paleoData...
# extracting: GodziszewskieLake.Miotk.1986
# extracting: Hudson.Clegg.2011
# extracting: ParkPond1.Lynch.1998
# extracting: ElGygytgynCrater.Schwamborn.2006
# extracting: Dalmutladdo.Bjune.2004
# extracting: GeoB10043_3.Setiawan.2015
# extracting: MD99_2341.Eynaud.2009
# extracting: CN01.Cheung.2017
# extracting: HumberPond5.McAndrews.1989
# extracting: TauldintreBrazi.Toth.2015
# extracting: LagunaSaladaChiprana.EPD
# extracting: PrazRodet.Shotyk.1997
# extracting: SaladaPequena.EPD
# extracting: Leviathan.Lachniet.2014
# extracting: BloodPond.Marsicek.2013
# extracting: Khatanga-12Lake.Syrykh.2017
# extracting: rainbow.Clegg.2011
# extracting: M77_2_024_5.Salvatteci.2019
# extracting: GeoB7926_2.Kim.2012
# extracting: LagoMoreno.Markgraf.2002
# extracting: PolandSpring.Jacobson.Ja
# extracting: MSM05-712.Muller.2013
# extracting: Gammelheimvatnet.Seppa.2009
# extracting: WCA3BGumboLimboMarsh.Willard.2001
# extracting: NussbaumerSeen.Rsch.1995
# extracting: DevonIslandGlacier.McAndrews.1984
# extracting: klotjarnen.Seppa.2009
# extracting: HLY03_05GC.Mohtadi.2008
# extracting: MD07-3088.Montade.2019
# extracting: Farewell.Hu.1998
# extracting: Cadagno.Niemann.2012
# extracting: TiancaiLake.Zhang.2017
# extracting: SudobleLake.Elovicheva.1985
# extracting: Delorme2.Bouchard.1982
# extracting: LakeStowell.Lemmen.2018
# extracting: LakeoftheWoods.Palmer.2002
# extracting: Toskaljavri.Seppa.2002
# extracting: Keele.Szeicz.1995
# extracting: RAPiD_12_1K.Thornalley.2010
# extracting: HjortSo.Wagner.2008
# extracting: vuoskkujavri.Bigler.2002
# extracting: HU84.deVernal.2013
# extracting: SouthernCalifornia.Ohlwein.2012
# extracting: PusciznaRekowianska.Obidowicz.1993
# extracting: MD01_2390.Steinke.2008
# extracting: WhitePond.Krause.2019
# extracting: SN-6.Tiwari.2015
# extracting: Hallet.McKay.2009
# extracting: Reidel.Almquist-Jacobson.1992
# extracting: PeatlandKlukva.Novenko.2015
# extracting: Trehorningen.Antonsson.2007
# extracting: CottonwoodPassPond.Fall.1997
# extracting: SaegistalseePollen.Wick.2003
# extracting: Rukatunturi.Hicks.1985
# extracting: RaigastvereLake.Pirrus.1987
# extracting: HAP0212.vanderBilt.2016
# extracting: TalkinTarn.Langdon.2004
# extracting: XingyunLake.Wu.2018
# extracting: MD84_527.Labracherie.1989
# extracting: SP02.Adams.2010
# extracting: Century.Johnsen.1972
# extracting: M40-4-SL78.Emeis.2003
# extracting: LacAurelie.Bajolle.2018
# extracting: Valiranta.Kharinei.2015
# extracting: LittleBass.Swain.NA
# extracting: 850Lake.Shemesh.2001
# extracting: GeoB10042_1.Setiawan.2015
# extracting: SchwarzseeReschenscheideck.Welten.1982
# extracting: KY07_04_PC1.Kubota.2010
# extracting: TN062-0550.Barron.2018
# extracting: KR02Chironomid.Fortin.2010
# extracting: MD84_527.Sarnthein.1988
# extracting: GeoB12605_3.Kuhnert.2014
# extracting: Duranunlak.EPD
# extracting: Moanatuatua.Jara.2017
# extracting: KaiteCobreMayor.MartinChivelet.2011
# extracting: CottonwoodLake.Grimm.1987
# extracting: Indian.Bjorck.1985
# extracting: DANA12_11_2_GC01.VanNieuwenhove.2018
# extracting: KNR166_14_11JPC.Elmore.2015
# extracting: Moon.Grimm.1996
# extracting: SchwarzseeobSoelden.Ilyashuk.2011
# extracting: H214.Samson.2005
# extracting: Eleanor.Gavin.2011
# extracting: Mohawk.Webb.1986
# extracting: LR1.Gajewski.1993
# extracting: MD98_2161.Fan.2018
# extracting: Alsopahok.Zatyko.2007
# extracting: M75_3_137_3.Wang.2013
# extracting: JM01-1199.Hald.2007
# extracting: M135_004_3.Salvatteci.2019
# extracting: Austerkjosen.Seppa.2009
# extracting: Nedlouc.Larouche.1981
# extracting: Haengstli.Heeb.1972
# extracting: MD03_2607-Assemblage.LopesdosSantos.2013
# extracting: Andy.Szeicz.1995
# extracting: Nutt.Bennett.1987
# extracting: LacGras.King.1986
# extracting: LO09-14.Berner.2008
# extracting: Mackenzie.Woltering.2014
# extracting: Isbenttjonn.Seppa.2009
# extracting: Skrzetuszewskie.Litt.2001
# extracting: Quartz.Wooller.2012
# extracting: Castor.Larouche.NA
# extracting: SouthIsland.Williams.2005
# extracting: GeoB3129_1.Weldeab.2006
# extracting: Holzmaar.Litt.2009
# extracting: GeoB1023_5.Kim.2002
# extracting: JPC42.Caniupan.2014
# extracting: BorderBeacon.Lamb.1985
# extracting: WachseldornUntermoos.Oeschger.1980
# extracting: Klotjaernen.Pollen.Sweden
# extracting: Igaliku.Massa.2012
# extracting: LacMeleze.MacDonald.1987
# extracting: BJ8_03_10GGC.Linsley.2010
# extracting: Mansell.Shuman.2016
# extracting: MSM055_712-2.Werner.2015
# extracting: Laihalampi.Giesecke.2008
# extracting: Flotatjonn.Seppa.2009
# extracting: Llet-T.liranta.2015
# extracting: Spaime.Hammarlund.2004
# extracting: TangledUpLake.Anderson.2001
# extracting: Little.Whitlock.1995
# extracting: MD94_103BAY.Sicre.2005
# extracting: Abalone.Cole.1994
# extracting: MD07-3104.Montade.2019
# extracting: Zbudovskablata.Rybnickova.1975
# extracting: M35003_4.R_hlemann.1999
# extracting: LacPetel.King.1986
# extracting: Queens.Moser.1990
# extracting: MooseLake.Clegg.2010
# extracting: Van.VanZeist.1978
# extracting: MLake.Ritchie.1977
# extracting: Hvitarvatn.Larsen.2013
# extracting: MD01-2416.Sarnthien.2004
# extracting: PogoniaBog.Cushing.1979
# extracting: MittlereHellelen.Welten.1982
# extracting: sjuuodjijaure.Rosen.2001
# extracting: Hinterburgseeli.EPD
# extracting: GIK23258_2.Martrat.2003
# extracting: SihailongwanMaar.Stebich.2015
# extracting: ODP658C.deMenocal.1997
# extracting: Lapland.Helama.2009
# extracting: Egelsee.Larocque.2010
# extracting: Kharinei.Jones.2011
# extracting: MD98_2181.Stott.2007
# extracting: KardashinskiSwamp.Kremenetski.1995
# extracting: KNR166_JPC51.Schmidt.2012
# extracting: SO189_119KL.Mohtadi.2014
# extracting: BJ8_03_13GGC.Linsley.2010
# extracting: Hail.Cwynar.1995
# extracting: Lynn.Nichols.1967
# extracting: MD02_2594.Dyez.2014
# extracting: MD07_3076Q.Gottschalk.2015
# extracting: MiddenCluster2.Harbert.2018
# extracting: MV1014_09MC.Hertzberg.2016
# extracting: NorthCraterLake.Palmer.2002
# extracting: Wonderkrater.Truc.2013
# extracting: JR01Chironomid.Fortin.2017
# extracting: HM03_133_25.Solignac.2008
# extracting: Compass.Macpherson.1986
# extracting: KinderlinskayaCave.Baker.2017
# extracting: AwengCo.Li.2017
# extracting: GraechenSee.Krisai.2006
# extracting: HiddenLakeCA.Potito.2006
# extracting: RC12-10.Poore.2003
# extracting: Naujg1.Willemse.1999
# extracting: NorthPond.Whitehead.1978
# extracting: MD02_2515.McClymont.2012
# extracting: Kinnshaugen.Seppa.2009
# extracting: ClarksJunction.Wilmshurst.2007
# extracting: MD07-3124.Caniupan.2014
# extracting: Windy.Chase.2008
# extracting: P178_15P.Tierney.2016
# extracting: Komosomolskaia.Ciais.1992
# extracting: Cranberry.McAndrews.NA
# extracting: Duck.Winkler.1985
# extracting: BaiedeSeineestuary.Garnaud.2003
# extracting: GiK18515_3
# extracting: PerchLake_ON.Terasmae.1975
# extracting: TourbieredeLanorieHenri.Comtois.1982
# extracting: Yanou.Foster.2016
# extracting: MD98_2165.Levi.2007
# extracting: TR163_22.Lea.2006
# extracting: PechoraLake.Andren.2015
# extracting: Boone.White.1986
# extracting: TwoYourtsLake.Nazarova.2013
# extracting: OCE326_GGC30.Sachs.2007
# extracting: MeerfelderMaar.Litt.2009
# extracting: Yakumo.Leipe.2013
# extracting: Uitbergen.Verbruggen.1979
# extracting: Kenosee.Porter.1992
# extracting: LacduSommet.Hausmann.2011
# extracting: RC24_08GC.Arbuszewski.2013
# extracting: MonheganIslandMeadow.Bostwick.1978
# extracting: Njakajaure.Bigler.2006
# extracting: SwietokrzyskieLake.Makohonienko.1991
# extracting: HopeSimpson.Engstrom.1985
# extracting: MiddenCluster4.Harbert.2018
# extracting: HU87033_87017PC.Andrews.1999
# extracting: ChallaLake.Damst.2012
# extracting: Altenweiher.DeValk.1981
# extracting: A7.Sun.2005
# extracting: HawkeHillsKettle.Macpherson.1982
# extracting: RC27_23.Overpeck.1996
# extracting: IOW225514BAY.Emeis.2003
# extracting: GeoB6518_1.Schefu.2005
# extracting: MD03_2707.Weldeab.2007
# extracting: SK237_GC04.Saraswat.2013
# extracting: VestreOykjamytjorn.Velle.2005
# extracting: MD97_2146.Shintani.2011
# extracting: MD97_2121.Pahnke.2006
# extracting: Reiarsdalvatnet.Seppa.2009
# extracting: SU81_18.Bard.2000
# extracting: BJ8_03_70GGC.Linsley.2010
# extracting: B997_327.Castaneda.2004
# extracting: SO90_56KA.Doose-Rolinski.2001
# extracting: Dye3.Vinther.2006
# extracting: ODP162_984.Came.2007
# extracting: DarzlubieForest.Polska-JasiewiczOwa.1996
# extracting: MD02_2575BAY.Ziegler.2008
# extracting: TN057-17.Nielsen.2004
# extracting: Flarken.Seppa.2005
# extracting: Gosciaz.Welten.1982
# extracting: Svartvatnet-Norway.Seppa.2009
# extracting: Atocas.Gauthier.1981
# extracting: LouisePond.Mathewes.1994
# extracting: MiddenCluster6.Harbert.2018
# extracting: Ospitale.Watson.1996
# extracting: PSh-5159N.Risebrobakken.2011
# extracting: Berkut.Ilyashuk.2005
# extracting: Lily.Cwynar.1990
# extracting: DavisLake.Barnosky.1981
# extracting: Malawi.Johnson.2016
# extracting: MD99-2227.deVernal.2013
# extracting: AdelaideTarn.Jara.2015
# extracting: Myrvatn.Seppa.2009
# extracting: JinchueanBog.Yu.2013
# extracting: Gass.Webb.1983
# extracting: NikolayLake.Andreev.2004
# extracting: Deltasoe.Axford.2019
# extracting: M77_2_029_3.Salvatteci.2019
# extracting: MSM05_5_712_2.Werner.2013
# extracting: brurskardstjorni.Velle.2005
# extracting: BattleGround.Whitlock.1985
# extracting: Sokli.Shala.2017
# extracting: LiivjarveBog.Koff.1989
# extracting: GeoB4905_4.Weldeab.2005
# extracting: Zabieniec.Plociennik.2011
# extracting: Stazersee.Heiri.2015
# extracting: D13882.Tierney
# extracting: Frozen.Rosenberg.2004
# extracting: PupukeChironomid.VandenBos.2018
# extracting: GYXO.Self.2015
# extracting: BebrukasLake.Shulija.1967
# extracting: MD03_2699.Rodrigues.2010
# extracting: LittleLochRoag.Birks.1979
# extracting: Haugtjern.Eide.2009
# extracting: PC_1.Chang.2015
# extracting: EDML.Stenni.2010
# extracting: PlateauRemote.MosleyThompson.1996
# extracting: B997_324.Castaneda.2004
# extracting: M77_2_003_2.Salvatteci.2019
# extracting: KNR195_5_CDH23.Bova.2015
# extracting: MD79_257.Bard.1997
# extracting: Decoy.Szeicz.1991
# extracting: MD95_2011.Risebrobakken.2003
# extracting: Ennadai-2.Nichols.1975
# extracting: Gemini.Samartin.2017
# extracting: Ladd.Shane.1993
# extracting: Demont.Kapp.NA
# extracting: MSM343300.Ouellet-Bernier.2014
# extracting: CoppermineSaddleback.Nichols.1975
# extracting: LR01.Gajewski.1993
# extracting: MD03-2601.Kim.2012
# extracting: ESM-1.Mackay.2012
# extracting: 3MPond.Pellatt.2000
# extracting: PupukePollen.VandenBos.2018
# extracting: MiddenCluster7.Harbert.2018
# extracting: MD03_2607.LopesdosSantos.2013
# extracting: Alley.GISP2.2000
# extracting: Irvin.Cushing.1982
# extracting: MD98_2188.Dang.2012
# extracting: MaleshevskaBog.Tonkov.1992
# extracting: Temje.Nazarova.2013
# extracting: Topptjonna.Paus.2011
# extracting: Tornetrask.Grudd.2002
# extracting: Lochnagar30.Dalton.2005
# extracting: Wachel3.Doerfler.1989
# extracting: Ratasjoen.Velle.2005
# extracting: PP10-07.Mary.2016
# extracting: HeshangCave.Wang.2018
# extracting: SaintCalixte.Larouche.NA
# extracting: SO189_039KL.Mohtadi.2014
# extracting: DempsterPeatland.Porter.2019
# extracting: VestreOykjamyrtorn.EPD
# extracting: MireSaviku.Sarv.1975
# extracting: Lingreville.Billard.1995
# extracting: BrayaSo.vonGunten.2012
# extracting: BoundaryPond.Mott.1977
# extracting: GB2.Gajewski.1993
# extracting: NA87_22.Duplessy.1992
# extracting: EC1.Gajewski.1993
# extracting: Station803.Bringue.2012
# extracting: WCA3BGumboLimboFarTail.Willard.2001
# extracting: EPICADomeC.Stenni.2010
# extracting: GIK23258.Sarnthein.2003
# extracting: Etangd'yCorMontana.Welten.1982
# extracting: Waxeckalm.Huettemann.1987
# extracting: KNR159_JPC26.Antonarakou.2015
# extracting: NGRIP.NGRIP.2004
# extracting: TourbieredeLanorieStJean.Comtois.1982
# extracting: PerchLake_Manitoba.Ritchie.NA
# extracting: OltushLake.EPD
# extracting: NorthLake.Axford.2013
# extracting: 2005-804-006.Ledu.2010
# extracting: MD79-257.Levi.2007
# extracting: GeoB3104_1.Arz.1998
# extracting: Beaverhouse.Ritchie.1976
# extracting: Agassiz.Lecavalier.2017
# extracting: Gould.Anderson.2008
# extracting: BiskupinskieLake.Noryskiewicz.1995
# extracting: SprucePond.Shuman.2016
# extracting: FanLake.Foster.2016
# extracting: SipleDomeA.Das.2008
# extracting: GeoB10069_3.Gibbons.2014
# extracting: DevonIceCap.Paterson.1977
# extracting: BeefPasture.Petersen.1985
# extracting: Sixteen.Futyma.1986
# extracting: GeoB7702_3.Castaneda.2010
# extracting: Arapisto.Sarmaja-Korjonen.2007
# extracting: Ruila.Seppa.2004
# extracting: Waskey.Levy.2004
# extracting: MSM055_723-2.Werner.2015
# extracting: Laihalampi.Heikkila.2003
# extracting: LaPAS_KF02.Pivel.2013
# extracting: LR3.Gajewski.1992
# extracting: Honeymoon.Cwynar.1991
# extracting: NIOP_C2_905_PC.Huguet.2006
# extracting: Svanavatnet.Bjune.2008
# extracting: GeoB9307_3.Weldeab.2014
# extracting: TK2.Porinchu.2019
# extracting: Glaswaldsee.EPD
# extracting: Breitnau-Neuhof.Roesch.2009
# extracting: Victoria.Berke.2012
# extracting: Szymbark.Szczepanek.1989
# extracting: Tsuolbmajavri.Korhola.2002
# extracting: Grostjorn.Eide.2009
# extracting: GIK17748-2.Kim.2002
# extracting: MD01-2446.Salguero.2014
# extracting: Grenadier.McAndrews.1988
# extracting: Menez-Cam.VanZeist.1964
# extracting: LacPatricia.McAndrews.1983
# extracting: NorthGRIP.Gkinis.2014
# extracting: WestOkoboji.VanZant.1979
# extracting: Lonespruce.Kaufman.2012
# extracting: VM28_122.Schmidt.2004
# extracting: EW0408_66JC.Praetorius.2015
# extracting: VM21_30.Koutavas.2003
# extracting: HU90_013_013.Hillaire-Marcel.1994
# extracting: LacFaribault.Larouche.1981
# extracting: LostLake_MI.Brubaker.1975
# extracting: ODP_175_1084B.Farmer.2005
# extracting: GeoB65181_MBT.Weijers.2007
# extracting: Sharkey.Shuman.2016
# extracting: StellaLake.Reinemann.2009
# extracting: KT05_7_PC_02.Kawahata.2009
# extracting: MoorimWeissenstadterForst.Hahne.1992
# extracting: GondoAlpjen.Welten.1982
# extracting: MD99-2322.Jennings.2011
# extracting: MiddenCluster9.Harbert.2018
# extracting: Giecz.Milecka.2002
# extracting: DYE3.Dahl-Jensen.1998
# extracting: KR02Pollen.Peros.2008
# extracting: BellsLake.Szeicz.1995
# extracting: KNR195_5_CDH26.Bova.2015
# extracting: MD95_2002.Eynaud.2012
# extracting: MD06_3067.Bolliet.2011
# extracting: MD01_2421.Isono.2009
# extracting: BanksIsland-15.Gajewski.2000
# extracting: GEOFAR_KF16_MgCa.Repschlager.2016
# extracting: Holebudalen.Seppa.2009
# extracting: Alsa.Mariscal.1993
# extracting: BledowoLake.Binka.1988
# extracting: Gilltjarnen.Antonsson.2006
# extracting: Kansjon.EPD
# extracting: Ylimysneva.Huttunen.1990
# extracting: Pella.Lim.2016
# extracting: Penny.Fisher.1998
# extracting: GISP2.Kobashi.2017
# extracting: Ximencuo.Herzschuh.2014
# extracting: Giering.Bortenschlager.1976
# extracting: Woryty.EPD
# extracting: Hypkana.Hajkova.2016
# extracting: Ferndale.Albert.1981
# extracting: MiddenCluster1.Harbert.2018
# extracting: GIK17051_3.Jung.1996
# extracting: Copley.Fall.1997
# extracting: CC04.Gibb.2015
# extracting: PannelBridge.Waller.1993
# extracting: CF8.Axford.2011
# extracting: Medvedevskoe.Nazarova.2018
# extracting: PuertodeLosTornos.Penalba.1989
# extracting: Njulla.Larocque.2004
# extracting: Gloppsjon.Seppa.2009
# extracting: Mendota.Winkler.1986
# extracting: HU90.deVernal.2013
# extracting: SSDP_102.Kim.2004
# extracting: Ammersee.vonGrafenstein.1996
# extracting: PotrokAike.Massaferro.2013
# extracting: Soylegrotta.Lauritzen.1999
# extracting: JR244_GC528.Roberts.2016
# extracting: ODP_175_1078C.Kim.2003
# extracting: Renland.Johnsen.1992
# extracting: Chuna.Jones.2005
# extracting: MD97_2141.Rosenthal.2003
# extracting: Billys.Jacobson.1975
# extracting: Longwoods.Wilmshurst.2007
# extracting: Steel.Shuman.2016
# extracting: ELake.Ritchie.1976
# extracting: GeoB5844_2.Arz.2003
# extracting: Olive-backedLake.Self.2015
# extracting: M77_2_059_1.N_rnberg.2015
# extracting: MD99_2251.Farmer.2008
# extracting: Svartvatnet-Svalbard.Luoto.2018
# extracting: GGC19.Farmer.2011
# extracting: Holtjaernen.Giesecke.2008
# extracting: ClearLakeIN.Bailey.1972
# extracting: PTHE.Self.2015
# extracting: Elfstadalsvatn.Langdon.2008
# extracting: NevadoHuascaran.Thompson.1995
# extracting: Chaohu.Li.2018
# extracting: MD01_2378.Xu.2008
# extracting: HU73_031_7.Keigwin.1995
# extracting: K2.Fallu.2005
# extracting: HLY0501.deVernal.2013
# extracting: Coghill.King.1986
# extracting: MiddenCluster5.Harbert.2018
# extracting: Hani.Zheng.2017
# extracting: SouthAfricanRainfallZone.Chevalier.2015
# extracting: WilderSeebeimRuhestein.EPD
# extracting: Moraine.Hansen.1985
# extracting: HavredeCrabec.Coutard.2006
# extracting: Sfl4-1.Willemse.1999
# extracting: Hirvijaervi.Luoto.2010
# extracting: WIND28K.Kiefer.2006
# extracting: Qinghai.Hou.2016
# extracting: Tanganyika.Tierney.2008
# extracting: Starvatn.Andresen.2008
# extracting: PL07_39PC.Lea.2003
# extracting: BanksIsland-12.Gajewski.2000
# extracting: Troll28-03.Klitgard-Kristensen.2001
# extracting: Straldzhamire.Tonkov.2009
# extracting: FontaineHenry.Lespez.2008
# extracting: Bjornfjell.Brooks.2006
# extracting: MD99-2269.Justwan.2008
# extracting: LacLeonard.Labelle.1984
# extracting: Flarken.Berglund.1966
# extracting: BS79_38.Cacho.2001
# extracting: MD98_2195.Ijiri.2005
# extracting: SO136_GC11.Barrows.2007
# extracting: ODP_165_999A.Schmidt.2004
# extracting: KoeycegizGoelue.EPD
# extracting: BolshieToroki.Zhilich.2017
# extracting: KeystoneIronbog.Fall.1985
# extracting: AlltnaFeitheSheilich.Birks.1975
# extracting: ERDC_092BX.Palmer.2003
# extracting: Bastien.Bennett.1987
# extracting: Graham.Fuller.1997
# extracting: Vuoksjavratje.Berntsson.2014
# extracting: GravelRidge.Lamb.1985
# extracting: P1B3.deVernal.2005
# extracting: GrandeBriere.Visset.1979
# extracting: GIK18287_3.Kienast.2001
# extracting: Radtke.Webb.1983
# extracting: AMP112.vanderBilt.2016
# extracting: B997_321.Castaneda.2004
# extracting: Berry.Whitehead.1979
# extracting: RC27_28.Overpeck.1996
# extracting: Basse-Ville.Voeltzel.1987
# extracting: LB1.Gajewski.1993
# extracting: ODP658C_UK37.Zhao.1995
# extracting: BN7Lake.Gajewski.1991
# extracting: LagoVerdarolo.Samartin.2011
# extracting: Ennadai-1.Nichols.1967
# extracting: MD01_2412.Harada.2006
# extracting: LagodeAjo.Allen.1996
# extracting: Donvold.Nilssen.1983
# extracting: GreyIslands.Cullen.2002
# extracting: TanaLake.Loomis.2015
# extracting: MD95_2015.Marchal.2002
# extracting: LeFourneau.Barbier.1999
# extracting: 165_1002C.Herbert.2000
# extracting: GIK17049_6.Jung.1996
# extracting: 31Lake.Eisner.1995
# extracting: OregonCaves.Ersek.2012
# extracting: MD02_2503.Hill.2006
# extracting: VuolepNjakajaure.Heinrichs.2006
# extracting: GeoB9310_4.Weldeab.2014
# extracting: ODP_167_1019C.Barron.2003
# extracting: JR01.Fortin.2017
# extracting: Hams.Bennett.1987
# extracting: Ostrowite.Milecka.2002
# extracting: StaroselskyMoch.Novenko.2018
# extracting: Churruca.Caniupan.2014
# extracting: Sluggan.Smith.1991
# extracting: Luganskoe.Kvavadze.1994
# extracting: RedRock.Maher.1972
# extracting: MD06_3075.Fraser.2014
# extracting: LagoDellAccesa.Finsinger.2010
# extracting: Hinterburgsee.Heiri.2015
# extracting: Dalene.Seppa.2009
# extracting: Eldora.Maher.1969
# extracting: PointEscuminac.Warner.1991
# extracting: TR163_31.Dubois.2009
# extracting: SV04.Rigual-Hernndez.2017
# extracting: EN32_PC6.Flower.2004
# extracting: Delorme1.Bouchard.1982
# extracting: RR1313_23PC.MoffaSanchez.2019
# extracting: DolgoeLake.Wolfe.2000
# extracting: Spannagel.Fohlmeister.2012
# extracting: MountHoney.McGlone.2010
# extracting: GeoB1711_4.Kirst.1999
# extracting: MD95_2043.Cacho.1999
# extracting: HU91-039-008.Levac.2001
# extracting: Camp11.Brubaker.1975
# extracting: KNR159_5_36GGC.Carlson.2008
# extracting: MD01-2444.Martrat.2007
# extracting: MV99_PC14.Marchitto.2010
# extracting: Pixie.Brown.2002
# extracting: HumberPond3.McAndrews.1989
# extracting: s53s52.KaislahtiTillman.2010
# extracting: Liltlvatn.Seppa.2009
# extracting: MD97_2151.Yamamoto.2013
# extracting: JPC67.Bertrand.2017
# extracting: 161_976.Martrat.2014
# extracting: M77_2_056_5.Neurnberg.2015
# extracting: PC6.Minoshima.2007
# extracting: LoughMeenachrinna.Taylor.2018
# extracting: LeGrandLemps.Clerc.1988
# extracting: IOW225517BAY.Emeis.2003
# extracting: VM12_107.Schmidt.2012
# extracting: Turkana.Berke.2012
# extracting: Corser.Nichols.2014
# extracting: Yarnyshnoe.Seppa.2008
# extracting: Myrtle.Janssen.1968
# extracting: Saint-JeanOrleans.Richard.1981
# extracting: SaintViaudContin.Bernard.1996
# extracting: GeoB12615_4.Romahn.2014
# extracting: LacMartyne.McAndrews.NA
# extracting: 117_723A.Godad.2011
# extracting: MaraisdeKeswick.Larouche.1986
# extracting: Kurupa.Boldt.2015
# extracting: HeihaiLake.Chang.2017
# extracting: WAISDivide.Fegyveresi.2016
# extracting: MD98_2176.Stott.2007
# extracting: Vostok.Vimeux.2002
# extracting: Lednica-1.Makohonienko.1991
# extracting: HU87033_87018PC.Andrews.1999
# extracting: LittlePondRoyalston.Marsicek.2013
# extracting: Tibetanus.Hammarlund.2002
# extracting: CangoCave.Talma.1992
# extracting: P1003.Sejrup.2011
# extracting: MD98_2178.Fan.2018
# extracting: Karujarv.EPD
# extracting: LoonPond.Jacobson.Ja
# extracting: WiggenhallSt.Germans.Waller.1994
# extracting: SO189_144KL.Mohtadi.2014
# extracting: Trettetjorn.Bjune.2005
# extracting: PlatypusTarn.Rees.2010
# extracting: ME0005A_43JC.Benway.2006
# extracting: High.Fuller.1997
# extracting: Vernerovice.Peichlova.1979
# extracting: KP2.Seppa.2009
# extracting: BiglandTarn.Barber.2013
# extracting: LV29_114_3.Riethdorf.2013
# extracting: EagleTarn.Rees.2010
# extracting: vikjordvatnet.Balascio.2012
# extracting: BC01Lake.Peros.2010
# extracting: DomeF.Uemura.2018
# extracting: M135_005_3.Salvatteci.2019
# extracting: CaribouHill.Lamb.1985
# extracting: SO90_63KA.Staubwasser.2003
# extracting: Nautajarvi.Seppa.2009
# extracting: MiddenCluster8.Harbert.2018
# extracting: Lyadhej-To.Andreev.2005
# extracting: Harrie.King.1986
# extracting: CascadeFen.Maher.1963
# extracting: MD99_2339.Eynaud.2009
# extracting: MD95_2011Assemblage.Risebrobakken.2003
# extracting: GB1.Gajewski.1991
# extracting: Lednica-2.Litt.1991
# extracting: 893A.Kennet.2007
# extracting: LagunaChaplin.Punyasena.2008
# extracting: SaintThomas.Voeltzel.1987
# extracting: TaulMuced.Diaconu.2017
# extracting: ClearLakeIA.Baker.1992
# extracting: GIK17940_2.Pelejero.1999
# extracting: Pingwang.Li.2018
# extracting: MD032601.Crosta.2007
# extracting: TALDICE.Mezgec.2017
# extracting: Tiavatnet.Seppa.2009
# extracting: Trout.Irvine.2012
# extracting: Iglutalik.Kerwin.2004
# extracting: MD99_2269.Kristjnsd_ttir.2017
# extracting: Hjort.Schmidt.2011
# extracting: Carp.Whitlock.1985
# extracting: Ranger.Brubaker.1983
# extracting: UpperFly.Bunbury.2009
# extracting: MD99-2266.Moossen.2015
# extracting: Haukdalsvatn.Larsen.2013
# extracting: SacredLake.Loomis.2012
# extracting: BI2Lake.Gajewski.1992
# extracting: Hamundarstadhahals.Caseldine.2006
# extracting: GreatBasin.Salzer.2014
# extracting: LoneFoxLake.MacDonald.1985
# extracting: AlpidiRobieiValBavona.Welten.1982
# extracting: HurlegLake.Zhao.2013
# extracting: BasadelaMoraLake.Tarrats.2018
# extracting: Lobsigensee.Ammann.1985
# extracting: MD03_2611.Calvo.2007
# extracting: MinnetonkaCave.Lundeen.2013
# extracting: RiviereFeuilles2.Larouche.1981
# extracting: MR003-K03-PC01.Harada.2004
# extracting: SaharaSandWetland.Rao.2019
# extracting: MD99-2284.Risebrobakken.2009
# extracting: CapeGhir.Kim.2007
# extracting: BoehnigseeGoldmoos.Markgraf.1969
# extracting: Nalengcuo.Opitz.2015
# extracting: Caribou-Qubec.Jett.1992
# extracting: KZAI_01.Hardy.2018
# extracting: JR51GC_35.Bendle.2007
# extracting: GeoB5901_2.Kim.2004
# extracting: Posy.Shafer.1989
# extracting: WAISDivide.Cuffey.2016
# extracting: Vatnamyri.Holmes.2011
# extracting: LakeLyadhej-To.Andreev.2005
# extracting: PolevaCave.Constantin.2007
# extracting: KNR166_JPC26.Schmidt.2011
# extracting: AgeroedsMosse.Nilsson.1964
# extracting: Nikolay.Andreev.2004
# extracting: ScreamingLynxLake.Clegg.2011
# extracting: LifebuoyLake.Solivieva.2015
# extracting: GeoB3910_2.Arz.2001
# extracting: M39008_3.Eynaud.2009
# extracting: MilandreCave.Affolter.2019
# extracting: GeoB10053_7.Mohtadi.2010
# extracting: GRIP.Vinther.2006
# extracting: EC2.Gajewski.1991
# extracting: MD99-2256.Jennings.2015
# extracting: Kaartlamminsuo.Rankama.1988
# extracting: Tigalmamine.Cheddadi.1998
# extracting: ClearPond.Hussey.1993
# extracting: JamesRossIsland.Mulvaney.2012
# extracting: Tumbulovaty.Kultti.2004
# extracting: Koucha.Herzschuh.2009
# extracting: FauskeCave.Linge.2009
# extracting: Rapid.Fall.1994
# extracting: Clapeyret.deBeaulieu.1977
# extracting: SwienskuhleDAHIII.Behre.1986
# extracting: JM96-1207.Solignac.2013
# extracting: Dura-Moor.Seiwald.1980
# extracting: Tarnowiec.Harmata.1987
# extracting: Sutherland.Shuman.2016
# extracting: AjaxBog.Wilmshurst.2007
# extracting: GeoB33131.Lamy.2002
# extracting: EW0408_85JC.Praetorius.2015
# extracting: Hanging.Cwynar.1982
# extracting: Gunnarsfjorden.Allen.2007
# extracting: PathLake.Neil.2014
# extracting: Devils.Shuman.2016
# extracting: HulunLake.Wen.2009
# extracting: AlanenLaanijarvi.Heinrichs.2005
# extracting: SO42_74KL.Huguet.2006
# extracting: OCE326_GGC26.Keigwin.2005
# extracting: Kyutyunda.Biskaborn.2016
# extracting: Raigastvere.Seppa.2004
# extracting: PL-96.Voronina.2013
# extracting: DajiuhuPeatland.Huang.2013
# extracting: LacColin.Mott.1977
# extracting: Isokaerret.Asplund.1989
# extracting: LawDome.Dahl-Jensen.1999
# extracting: CH2.Garralla.1992
# extracting: TTR17_434G.Rodrigo-Gamiz.2014
# extracting: BuntesMoor.Weirich.1980
# extracting: HomesteadScarp.McGlone.2010
# extracting: MD97_2120.Pahnke.2006
# extracting: CandelabraLake.Cwynar.1995
# extracting: SecretLake.Lasher.2017
# extracting: Kusawa.Chakraborty.2010
# extracting: ODP_178_1098B.Shevenell.2011
# extracting: MoorAlpenrose.Weirich.1980
# extracting: CarletonLake.Upiter.2014
# extracting: GeoB17419_1.Hollstein.2018
# extracting: Jake.Kerwin.2005
# extracting: MiddenCluster3.Harbert.2018
# extracting: Qipisarqo.Frechette.2009
# extracting: Zalozhtsy.Bezusko.1992
# Created time series: 5088 entries
# CPU times: user 6.02 s, sys: 845 ms, total: 6.86 s
# Wall time: 7.21 s

# %% [markdown]
# Filter all the series to extract the calibrated temperature series <a name="filter"></a>

# %%
filtered_ts_temp12k = lipd.filterTs(all_series,'paleoData_inCompilation == Temp12k')
temperatures = lipd.filterTs(filtered_ts_temp12k,'paleoData_units == degC')
# Out:
# Found 1319 matches from 5088 columns
# Found 1276 matches from 1319 columns

# %% [markdown]
# ## Conversion to pandas
# Now that we have the time-series, we transform them to a [pandas.DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html). This allows us to use groupby and other database measures.

# %% [markdown]
# For this purpose, we first define a few meta data attributes that should be kept for every record.
#
# - `meta_cols` is the attribute in the dictionary of the individual time series. If the attribute is within a key or list, you can separate them by a single `.`.
#
#   `paleoData_interpretation.0.seasonalityGeneral`
#
#   for instance will be interpreted as
#
#   `d['paleoData_interpretation'][0]['seasonalityGeneral']`
# - `meta_names` is the name of the corresponding attribute in `meta_cols` how it should be saved in the dataframe

# %%
meta_cols = ['geo_meanLon', 'geo_meanLat', 'dataSetName', 'paleoData_variableName', 'paleoData_TSid', 
             'paleoData_interpretation.0.seasonalityGeneral', 'paleoData_datum', 'paleoData_proxy']
meta_names = ['lon', 'lat', 'dataSetName', 'variableName', 'TSid', 'seasonality', 'datum', 'proxy']

# %% [markdown]
# Then every dictionary in `temperatures` is converted to a pandas datafram

# %%
frames = []
failures = []
for d in pg.utils.log_progress(temperatures):
    if 'age' in d:
        try:
            s = pd.Series(
                np.asarray(d['paleoData_values'], dtype=float),
                index=pd.Index(np.asarray(d['age'], dtype=float), name='age'),
                name='temperature')
        except ValueError:
            failures.append(d)
        else:
            # keep NaN of ages, these are filtered out later
            s = s[(~np.isnan(s.index)) & (s.index > -70 ) & (s.index < 14000)]
            # if the time series has (in average) more than one sample per
            # decade, we use decadal averages
            if s.size > 1470:
                s = s.groupby(lambda i: 5 + i - (i % 10)).mean()
                s.index.name = 'age'
            s.index.name = 'age'
            frame = s.to_frame().reset_index()
            for i, name in enumerate(meta_cols):
                sub = d
                vals = name.split('.')
                name = vals[-1]
                for v in vals[:-1]:
                    sub = sub[v if isinstance(sub, dict) else int(v)]
                frame[meta_names[i]] = sub.get(name, np.nan)
            frames.append(frame)
print(f"Failed to read {len(failures)} time series")
# Out:
# Starting at 2020-04-17 20:49:06.189962
# |████████████████████████████████████████████████████████████████████████████████| 100.0% Time left: 0.000 minutes
# Finished at 2020-04-17 20:49:11.346282. Time needed: 0.086 minutes
# Failed to read 0 time series

# %% [markdown]
# Now we concatenate everything into one large dataframe

# %%
df = pd.concat(frames, ignore_index=True)
df.head()
# Out:
#       age  temperature    lon    lat                   dataSetName  \
# 0  212.13    -2.045714  18.55  54.09  GodziszewskieLake.Miotk.1986
# 1  275.05    -4.110000  18.55  54.09  GodziszewskieLake.Miotk.1986
# 2  337.83    -3.375714  18.55  54.09  GodziszewskieLake.Miotk.1986
# 3  427.04    -2.907143  18.55  54.09  GodziszewskieLake.Miotk.1986
# 4  515.32    -4.094286  18.55  54.09  GodziszewskieLake.Miotk.1986
#
#   variableName         TSid seasonality datum   proxy
# 0  temperature  RFzafiT2i0G     winter+   abs  pollen
# 1  temperature  RFzafiT2i0G     winter+   abs  pollen
# 2  temperature  RFzafiT2i0G     winter+   abs  pollen
# 3  temperature  RFzafiT2i0G     winter+   abs  pollen
# 4  temperature  RFzafiT2i0G     winter+   abs  pollen

# %% [markdown]
# ### Estimation of uncertainties

# %% [markdown]
# The age uncertainty is estimated such, that it is 50 years at 0 BP and 250 years at 12k BP

# %%
df['age_unc'] = 50 + df.age * (250 - 50) / 12000

# %% [markdown]
# The temperature uncertainty is estimated per proxy and per season <a name="temp-unc"></a>

# %%
uncertainties = pd.read_excel(
    '../data/proxy-uncertainties.xlsx', sheet_name='Summary', 
    index_col='proxy', usecols=[0, 1, 2, 3])
uncertainties
# Out:
#                                                       summer    winter  \
# proxy
# pollen                                              2.017837  3.012946
# other microfossils/dinocyst                         1.700000  1.200000
# chironomid                                          1.399705       NaN
# other microfossils/diatoms                          1.122375       NaN
# other microfossils/radiolaria                       1.200000       NaN
# other microfossils/foraminifera                     1.325000  1.412500
# alkenone                                                 NaN       NaN
# MgCa                                                1.850000  1.850000
# GDGT (MBT/CBT as well as BrGDGT fractional abun...       NaN       NaN
# GDGT (Tex86)                                             NaN       NaN
# d18O                                                     NaN       NaN
# NaN                                                      NaN       NaN
# NaN                                                      NaN       NaN
# mean of all values                                       NaN       NaN
# median of all values                                     NaN       NaN
# 75th percentile of all values                            NaN       NaN
# 75th percentile of all values without d18O               NaN       NaN
#
#                                                       annual
# proxy
# pollen                                              2.105745
# other microfossils/dinocyst                         1.200000
# chironomid                                               NaN
# other microfossils/diatoms                               NaN
# other microfossils/radiolaria                            NaN
# other microfossils/foraminifera                     1.282500
# alkenone                                            1.650000
# MgCa                                                1.850000
# GDGT (MBT/CBT as well as BrGDGT fractional abun...  2.902857
# GDGT (Tex86)                                        2.333333
# d18O                                                2.100000
# NaN                                                      NaN
# NaN                                                      NaN
# mean of all values                                  1.763937
# median of all values                                1.700000
# 75th percentile of all values                       2.058918
# 75th percentile of all values without d18O          1.975878

# %%
uncertainty_map = {
    'dinocyst': 'other microfossils/dinocyst',
    'pollen': 'pollen', 
    'chironomid': 'chironomid',
    'alkenone': 'alkenone',
    'GDGT': 'GDGT (MBT/CBT as well as BrGDGT fractional abundance)',
    'Mg/Ca': 'MgCa',
    'macrofossils': 'macrofossils',
    'bubble frequency': 'bubble frequency',
    'borehole': 'borehole',
    'C15 fatty alcohols': 'C15 fatty alcohols',
    'd18O': 'd18O',
    'radiolaria': 'other microfossils/radiolaria',
    'foraminifera': 'other microfossils/foraminifera',
    'dD': 'dD',
    'd13C': 'd13C',
    'diatom': 'other microfossils/diatoms',
    'isotope diffusion': 'isotope diffusion',
    'TRW': 'TRW',
    'hybrid-ice': 'hybrid-ice',
    'deterium excess': 'deterium excess',
    'gas': 'gas',
    'chlorophyll': 'chlorophyll',
    'melt layer': 'melt layer',
    '3-OH-Fatty Acids': '3-OH-Fatty Acids',
    'TEX86': 'GDGT (Tex86)',
    'LDI': 'LDI',
    'long chain diol': 'long chain diol'
}
uncertainty_map_inv = {val: key for key, val in uncertainty_map.items()}

# %%
df['seas'] = np.nan
seasonality = df.seasonality.fillna('')
df.loc[seasonality.str.startswith('summer'), 'seas'] = 'summer'
df.loc[seasonality.str.startswith('winter'), 'seas'] = 'winter'
df.loc[seasonality.str.startswith('annual'), 'seas'] = 'annual'

# %%
last = uncertainties.isnull().all(axis=1)
uncertainties = uncertainties.iloc[:np.argmax(last.values)]
# default uncertainty: 75th percentile of all values without d18O
df['temp_unc'] = 1.975877719
for proxy, row in uncertainties.iterrows():
    for seas, val in row[row.notnull().values].items():
        mask = (df.proxy == uncertainty_map_inv[proxy]) & (df.seas == seas)
        df.loc[mask.values, 'temp_unc'] = val

# %%
import seaborn as sns
ax = sns.stripplot('proxy', 'temp_unc', data=df)
for t in ax.get_xticklabels():
    t.set_rotation(90)

# %% [markdown]
# Now we filter out samples that have unrealistic temperatures, or no seasonality <a name="filter-nan"></a>.

# %%
df.loc[~df.temperature.between(-200, 200).values, 'temperature'] = np.nan

# %%
for col in ['seasonality', 'temperature']:
    print(f'NaN for {col}: {df[col].isnull().sum()}')
# Out:
# NaN for seasonality: 0
# NaN for temperature: 10641

# %%
print(df.shape)
df.dropna(subset=['seasonality', 'temperature'], inplace=True)
print(df.shape)
# Out:
# (121457, 13)
# (110816, 13)

# %% [markdown]
# ## Computation of the grid cell anomalies <a name="cell-anomalies"></a>
#
# Now that the input data is filtered and ready to use, we compute the anomalies per grid cell. For this purpose, we use the `GAMEnsemble` class defined in [gam_ensemble.py](gam_ensemble.py).
#
# We use all annual records, and, if there is only a summer or winter record available in the LiPD dataset, we use this one as well.

# %%
with psyd.open_dataset('../data/equal-area-grid-N4000.nc') as _ds:
    output_ds = _ds.load()
area = output_ds['cell_area']
output_ds['time'] = time = xr.Variable(
    ('time', ), np.arange(12000, -50, -100),
    attrs = {'long_name': 'Age', 'units': 'years since 1950-01-01'})
output_ds['temperature'] = xr.Variable(
    ('time', area.dims[0]), np.full((time.size, area.size), np.nan),
    encoding = dict(coordinates='clat clon'))

ensemble = ge.GAMEnsemble(
    df[(df.seasonality == 'annual') | 
       (df.seasonality == 'summerOnly') | 
       (df.seasonality == 'winterOnly')].set_index('age'), 
    target=output_ds.psy['temperature'],
    climate='temperature', ds_id='TSid')

# %% [markdown]
# ### Generate the ensemble
# For age, we use a gibbs sampling algorithm to generate an ensemble of 500 ages per sample. For temperature, we use a normal distribution defined by the temperature of the sample and the uncertainty [estimated above](#temp-unc).

# %%
# %%time
ds = ensemble.input_data
ages = ensemble.sample_ages(size=500, use_dask=False)
ds['age_ensemble'] = ages.load()
ds['temperature_ensemble'] = ages.rename('temperature_ensemble').copy(
    data=np.random.normal(ds.temperature, ds.temp_unc,
                          size=ages.shape))
# Out:
# CPU times: user 47.2 s, sys: 241 ms, total: 47.5 s
# Wall time: 47.5 s

# %% [markdown]
# We save the input data to share it with others

# %%
output_dir = f'../output_{db_version}'
# !mkdir -p {output_dir}

# %%
to_keep = [
    'dataSetName',
    'variableName',
    'seasonality',
    'datum',
    'proxy',
    'age_unc',
    'seas',
    'temp_unc',
    'age_ensemble',
    'temperature_ensemble'
]

key = 'annual-with-single-seas'

ds = ensemble.input_data[to_keep]
encoding = {v: dict(zlib=True, complevel=4)
            for v in ds.variables}
for var in ds.variables:
    if np.issubdtype(ds[var].dtype, np.number):
        encoding[var]['least_significant_digit'] = 5
ofile = f'{output_dir}/{key}_input.nc'
ds.rename_dims(age='sampleId').to_netcdf(
    ofile, encoding=encoding)

# %% [markdown]
# ### Computation of grid cell anomalies
# The heavy part comes now, we compute the grid cell anomalies and save them to `annual-with-single-seas-gam-ref-5000-3000-bp.nc`.

# %%
n_workers = 64

cluster = SLURMCluster(cores=1, dashboard_address=":33913", walltime="03:00:00")
cluster.scale(n_workers)

try:
    with Client(cluster) as client:
        with warnings.catch_warnings() as c:
            warnings.filterwarnings('ignore', '\s*indexing past lexsort depth')
            output = ensemble.predict(
                size=500, client=client, use_gam=True, return_counts=100, max_time_diff=14000,
                modern_young=3000, modern_old=5000)
            output['time'].values *= -1
            output.to_netcdf(f'{output_dir}/{key}-gam-ref-5000-3000-bp.nc')
finally:
    cluster.close()
# Out:
# Starting at 2020-04-17 20:50:23.437711
# |████████████████████████████████████████████████████████████████████████████████| 100.0% Time left: 0.042 minutes
# Finished at 2020-04-17 21:04:09.345651. Time needed: 13.765 minutes

# %% [markdown]
# We only want to use the gam prediction if
#
# - there has been more than 100 samples between 5k and 3k BP in the ensemble
# - there were at least 100 samples in the surrounding 300 years of the time of prediction

# %%
# valid = output.nsamples.sel(time=slice(-5000, -3000)).sum(dim='time')
valid = output.nsamples.where((output.time > -5000) & (output.time < -3000), drop=True).sum(dim='time')
surrounding = output.nsamples.rolling(time=3).sum()

# %%
output = output.where(valid > 100)
output = output.where(surrounding > 100)

# %% [markdown]
# ## Computation of latitudinal bands
# In the last part of this analysis we compute the mean of the individual latitudinal bands. We are using an equal-area grid here, as such, we do not have to worry about the latitudinal weighting.

# %%
bands = []
with warnings.catch_warnings() as c:
    warnings.filterwarnings('ignore', '\s*Mean of empty slice')
    for lat in pg.utils.log_progress(np.arange(-90, 90, 30)):
        idx = np.where(output.clat - (output.clat % 30) == lat)[0]
        sel = output.isel(cell=idx)
        band = sel.mean('cell')
        
        # compute the sum for the number of samples and the cell_area
        band['nsamples'] = sel.nsamples.sum('cell')
        band['cell_area'] = sel.cell_area.sum('cell')
        band['lat'] = ((), lat + 15)
        bands.append(band)
bands = xr.concat(bands, dim='lat')
# Out:
# Starting at 2020-04-17 21:04:21.660716
# |████████████████████████████████████████████████████████████████████████████████| 100.0% Time left: 0.011 minutes
# Finished at 2020-04-17 21:04:25.294907. Time needed: 0.061 minutes

# %% [markdown]
# Compute the standard deviation from the ensemble

# %%
bands['temperature_std'] = bands.temperature_samples.std('ens')
# Out:
# /gpfs/home/sommerp/miniconda3/envs/temperature12k/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1667: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %% [markdown]
# Plot the anomalies of the individual bands

# %%
sp = bands.psy.plot.lineplot(
    name=[[['temperature', 'temperature_std']]],
    lat=list(range(6)), legendlabels='%(lat)s',
    xlabel='Time [years since 1950-01-01]',
    ylabel='Temperature anomaly to 5000-3000 yr cal BP [°C]',
    xlim='minmax', 
    legend=dict(loc='upper center', ncol=6, bbox_to_anchor=(0.5, 1.3),
                title='Center of latitudinal band [°N]'))

plt.gcf().set_dpi(300)

# %% [markdown]
# Compute the samples per band that have been used. There is an nsamples variable already in the file, but this one is based on the entire ensemble.

# %%
nsamples = ensemble.input_data.age.groupby_bins('lat', range(-90, 91, 30)).apply(
    lambda da: da.groupby_bins(da, np.arange(-50, 12051, 100)).apply(
        lambda da: xr.DataArray(np.unique(da.TSid).size)))
nsamples['lat_bins'] = ('lat_bins', [i.mid for i in nsamples.lat_bins.values])
nsamples['age_bins'] = ('age_bins', [i.mid for i in nsamples.age_bins.values])

# %%
nsamples.to_dataset(name='nsamples').psy.plot.lineplot(
    lat_bins=list(range(6)), legendlabels='%(lat_bins)s',
    ylabel='Number of individual records', xlabel='Age yr cal BP',
    xlim='minmax', 
    legend=dict(loc='upper center', ncol=6, bbox_to_anchor=(0.5, 1.3),
                    title='Center of latitudinal band [°N]'))
plt.gcf().set_dpi(250)
plt.gca().invert_xaxis()

# %%
bands = bands.rename({'nsamples': 'nsamples_ens'})
bands['nsamples'] = nsamples.rename({'lat_bins': 'lat', 'age_bins': 'age'})

# %%
bands.to_netcdf(f'{output_dir}/annual-with-single-seas-gam-band-means.nc',
                encoding={var: {'complevel': 4, 'zlib': True} 
                          for var in bands.variables})
